# %% [markdown]
# ### In RNN_CNN.ipynb file, we build CNN and RNN models for image data and noisyTextDescription. After training, we get 3 model files(best.h5, char_rnn_classification_model_lstm.pt and char_rnn_classification_model_gru.pt). We will process all of them together in overall.ipynb.

# %% [markdown]
# # Load Data from Google Drive
#
# ---

# %%
from google.colab import files
uploaded = files.upload()
# %ls
# Out:
#      <input type="file" id="files-d25a0536-46d0-4cde-9845-2dc2452fdd8b" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-d25a0536-46d0-4cde-9845-2dc2452fdd8b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>

# %% [markdown]
# # Import Library

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder

import time
from torch.optim import Adam
import torch.nn as nn
from torch.nn import Linear, ReLU, CrossEntropyLoss, Sequential, Conv2d, MaxPool2d, Module, Softmax, BatchNorm2d, Dropout
import torch

# %% [markdown]
# # Using RNN to predict categories with noisyTextDescription

# %%
import string 

df_train, df_test = load_data()

n_train_data = len(df_train)
n_test_data = len(df_test)
all_letters = string.ascii_letters + '0123456789&-\' '
n_letters = len(all_letters)
all_categories = list(np.unique(np.array(df_train['category'])))
n_categories = len(all_categories)

train_overall = np.array(df_train[['id','category', 'noisyTextDescription']])
train_data = np.array(df_train['noisyTextDescription'])
test_id = np.array(df_test['id'])
test_data = np.array(df_test['noisyTextDescription'])

# %%
import torch

# Find letter index from all_letters, e.g. "a" = 0
def letterToIndex(letter):
    return all_letters.find(letter)

# Just for demonstration, turn a letter into a <1 x n_letters> Tensor
def letterToTensor(letter):
    tensor = torch.zeros(1, n_letters)
    tensor[0][letterToIndex(letter)] = 1
    return tensor

# Turn a line into a <line_length x 1 x n_letters>,
# or an array of one-hot letter vectors
def lineToTensor(line):
    tensor = torch.zeros(len(line), 1, n_letters)
    for li, letter in enumerate(line):
        tensor[li][0][letterToIndex(letter)] = 1
    return tensor

# %%
import random
import math

# Build the category_lines dictionary, a list of names per category
category_lines = {}
train_data = {}
validation_data = {}
test_data = {}

for category in all_categories:
  train_data[category] = []

for i in range(n_train_data):
  category = train_overall[i][0]
  train_data[category].append(train_overall[i][1])

for category in all_categories:
    lines = train_data[category]
    random.shuffle(lines)
    train_data[category] = lines[0:int(math.floor(0.7*len(lines)))]
    validation_data[category] = lines[int(math.floor(0.7*len(lines)))+1:int(math.floor(0.85*len(lines)))]
    test_data[category] = lines[int(math.floor(0.85*len(lines)))+1:]
    category_lines[category] = lines

# %% [markdown]
# ## Create RNN models (LSTM and GRU)

# %%
import torch.nn as nn
from torch.autograd import Variable

class RNN_LSTM(nn.Module):
    def __init__(self, input_size, hidden_size, output_size):
        super(RNN_LSTM, self).__init__()

        self.hidden_size = hidden_size
        self.lstm_cell = nn.LSTMCell(input_size, hidden_size)
        self.i2o = nn.Linear(input_size + hidden_size, output_size)
        self.softmax = nn.LogSoftmax(dim=1)

    def forward(self, input, hidden, cell):
        combined = torch.cat((input, hidden), 1)
        hidden, cell = self.lstm_cell(input,(hidden,cell))
        output = self.i2o(combined)        
        output = self.softmax(output)
        return output, hidden, cell

    def initHidden(self):
        return Variable(torch.zeros(1, self.hidden_size)), Variable(torch.zeros(1, self.hidden_size))
    
class RNN_GRU(nn.Module):
    def __init__(self, input_size, hidden_size, output_size):
        super(RNN_GRU, self).__init__()

        self.hidden_size = hidden_size
        self.gru_cell = nn.GRUCell(input_size, hidden_size)
        self.i2o = nn.Linear(input_size + hidden_size, output_size)
        self.softmax = nn.LogSoftmax(dim=1)

    def forward(self, input, hidden):
        combined = torch.cat((input, hidden), 1)
        hidden = self.gru_cell(input,hidden)
        output = self.i2o(combined)        
        output = self.softmax(output)
        return output, hidden

    def initHidden(self):
        return Variable(torch.zeros(1, self.hidden_size))
    
n_hidden = 128
rnn_lstm = RNN_LSTM(n_letters, n_hidden, n_categories)
rnn_gru = RNN_GRU(n_letters, n_hidden, n_categories)

# %% [markdown]
# ## Trainning

# %% [markdown]
# ### Prepare for trainning

# %%
criterion_lstm = nn.NLLLoss()
criterion_gru = nn.NLLLoss()

lstm_optimizer = torch.optim.Adam(rnn_lstm.parameters())
gru_optimizer = torch.optim.Adam(rnn_gru.parameters())

def train(category_tensor, line_tensor):
    hidden_lstm, cell_lstm = rnn_lstm.initHidden()
    hidden_gru = rnn_gru.initHidden()

    # reset gradient
    rnn_lstm.zero_grad()
    rnn_gru.zero_grad()

    for i in range(line_tensor.size()[0]):
        output_lstm, hidden_lstm, cell_lstm = rnn_lstm(line_tensor[i], hidden_lstm, cell_lstm)
        output_gru, hidden_gru = rnn_gru(line_tensor[i], hidden_gru)

    loss_lstm = criterion_lstm(output_lstm, category_tensor)
    loss_gru = criterion_gru(output_gru, category_tensor)

    # compute gradient by backpropagation
    loss_lstm.backward()
    loss_gru.backward()

    # update parameters
    lstm_optimizer.step()
    gru_optimizer.step()

    return output_lstm, loss_lstm.item(), output_gru, loss_gru.item()

# %%
def categoryFromOutput(output):
    top_n, top_i = output.topk(1)
    category_i = top_i[0].item()
    return all_categories[category_i], category_i
    
import random

def randomChoice(l):
    return l[random.randint(0, len(l) - 1)]

def randomTrainingExample():
    category = randomChoice(all_categories)
    line = randomChoice(train_data[category])
    category_tensor = torch.tensor([all_categories.index(category)], dtype=torch.long)
    line_tensor = lineToTensor(line)
    return category, line, category_tensor, line_tensor

for i in range(10):
    category, line, category_tensor, line_tensor = randomTrainingExample()
    print('category =', category, '/ line =', line)
# Out:
# category = Dress / line = Custom White Floral Design Dress
# category = Cufflinks / line = Jamaica Men Steel Cufflinks
# category = Topwear / line = UCB N9336SL03 NA2394SL02 Hazel Cl Top
# category = Bags / line = Nike Noisy Blue Lt.khaki France 661 Backpack
# category = Innerwear / line = Amante Women Tango Seamless Briefs PCSN02
# category = Eyewear / line = Polaroid Unisex Sunglasses
# category = Dress / line = Tonga Women Honeysuckle Dress
# category = Innerwear / line = Lovable Women Tease Pink Bra
# category = Dress / line = Avirate Women toned Dress
# category = Sandal / line = Crocs Dora Boots Pink I071

# %%
def evaluate(line_tensor):
    hidden_lstm, cell_lstm = rnn_lstm.initHidden()
    hidden_gru = rnn_gru.initHidden()
    for i in range(line_tensor.size()[0]):
        output_lstm, hidden_lstm, cell_lstm = rnn_lstm(line_tensor[i], hidden_lstm, cell_lstm)
        output_gru, hidden_gru = rnn_gru(line_tensor[i], hidden_gru)
    return output_lstm, output_gru 

def eval_dataset(dataset):
    loss_lstm = 0
    loss_gru = 0
    n_instances = 0
    confusion_lstm = torch.zeros(n_categories, n_categories)
    confusion_gru = torch.zeros(n_categories, n_categories)
    for category in all_categories:
        category_tensor = Variable(torch.LongTensor([all_categories.index(category)]))
        n_instances += len(dataset[category])
        category_i = all_categories.index(category)
        for line in dataset[category]:
            line_tensor = Variable(lineToTensor(line))
            output_lstm, output_gru = evaluate(line_tensor)
            
            loss_lstm += criterion_lstm(output_lstm, category_tensor)
            guess_lstm, guess_i_lstm = categoryFromOutput(output_lstm)
            confusion_lstm[category_i][guess_i_lstm] += 1

            loss_gru += criterion_gru(output_gru, category_tensor)
            guess_gru, guess_i_gru = categoryFromOutput(output_gru)
            confusion_gru[category_i][guess_i_gru] += 1

    # Normalize by dividing every row by its sum
    for i in range(n_categories):
        confusion_lstm[i] = confusion_lstm[i] / confusion_lstm[i].sum()
        confusion_gru[i] = confusion_gru[i] / confusion_gru[i].sum()

    return loss_lstm.item() / n_instances, confusion_lstm, loss_gru.item() / n_instances, confusion_gru

# %%
import time
import math

n_iters = 20000
print_every = 5000
plot_every = 1000

# Keep track of losses for plotting
train_loss_lstm = 0
train_loss_gru = 0
all_train_losses_lstm = []
all_train_losses_gru = []
all_validation_losses_lstm = []
all_validation_losses_gru = []

def timeSince(since):
    now = time.time()
    s = now - since
    m = math.floor(s / 60)
    s -= m * 60
    return '%dm %ds' % (m, s)
  
print('\nIter \tTrain% \tTime \t \tTrain_loss_LSTM \tTrain_loss_GRU \tExample')
start = time.time()
for iter in range(1, n_iters + 1):
    category, line, category_tensor, line_tensor = randomTrainingExample()
    output_lstm, loss_lstm, output_gru, loss_gru = train(category_tensor, line_tensor)
    train_loss_lstm += loss_lstm
    train_loss_gru += loss_gru

    # Print iter number, train loss average, name and guess
    if iter % print_every == 0:
        guess, guess_i = categoryFromOutput(output_lstm)
        correct = 'âœ“' if guess == category else 'âœ— (%s)' % category
        print('%d \t%d%% \t(%s) \t%.4f \t\t\t%.4f \t\t%s / %s %s' % (iter, iter / n_iters * 100, timeSince(start), train_loss_lstm / plot_every, train_loss_gru / plot_every, line, guess, correct))

    # Add current train loss average to list of losses
    if iter % plot_every == 0:
        all_train_losses_lstm.append(train_loss_lstm / plot_every)
        all_train_losses_gru.append(train_loss_gru / plot_every)
        train_loss_lstm = 0
        train_loss_gru = 0
        
    # Compute loss based on validation data
    if iter % plot_every == 0:
        average_validation_loss_lstm, _, average_validation_loss_gru, _ = eval_dataset(validation_data)

        # save model with best validation loss
        if len(all_validation_losses_lstm) == 0 or average_validation_loss_lstm < min(all_validation_losses_lstm):
            torch.save(rnn_lstm, 'char_rnn_classification_model_lstm.pt')
        all_validation_losses_lstm.append(average_validation_loss_lstm)
        if len(all_validation_losses_gru) == 0 or average_validation_loss_gru < min(all_validation_losses_gru):
            torch.save(rnn_gru, 'char_rnn_classification_model_gru.pt')
        all_validation_losses_gru.append(average_validation_loss_gru)
# Out:
# Iter 	Train% 	Time 	 	Train_loss_LSTM 	Train_loss_GRU 	Example
# 5000 	25% 	(5m 47s) 	1.1422 			1.0697 		Water Chronograph Sandwichtost MW-600F-7AVDF(A507) Watch / Watches âœ— (Free Gifts)
# 10000 	50% 	(12m 34s) 	0.9300 			0.7907 		Fossil Men Brown Wallet / Wallets âœ“
# 15000 	75% 	(19m 26s) 	0.7321 			0.6133 		Murcia Women Brown & White Bag / Accessories âœ— (Bags)
# 20000 	100% 	(26m 20s) 	0.6608 			0.5355 		Lotus ace Plum Mist Nail Polish 952 / Nails âœ“

# %%
print(test_data)
# Out:
# {'Accessories': ['Bonn Men Formal Red Accessory Request Set', 'Cabarelli Men Black G-SHOCK AE-1100W-1AVDF(D085) Set', 'Arrow Men Formal Purple Addict square - Affairs Pack', 'Vital Gear Unisex Black Messenger Alpinist', 'ME1114 Perros Men Boy Distresse Accessory Gift Set', 'Lino Perros Men Formal Valaya Latino Gift Set', 'Lino Snow Men Formal BTS Accessory Gift Set', 'Lino Perros 0380 Formal Black Accessory Gift Set', 'Wildcraft Unisex Bwd Travel Pouch'], 'Apparel Set': ['Velcro Women Rap Churidar Kurta with Dupatta', 'Little Miss Girls Chatterbox Blue W13564L1 Comfort', 'Ayaany Women Teal & Purple Embroidered Mar Lunareclipse with Dupatta', 'EX0320-50A Women Purple Potion TH1790770-D ED152 Churidar ADH2651 with Dupatta', 'Vishudh Women Red Pullover Navy Churidar Kurta with Dupatta', 'ADIDAS Women Swimming Purple Cap', 'Abstract Women Race Treviso Green Printed Swerve Supa Moustaches Dupatta', 'Little Miss Girls Pontoise Red Clothing Set'], 'Bags': ['Ground Unisex Blue Jefford Grey Backpack', 'Murcia Women Seoul Leatherite Handbag', 'She Unisex Red Backpack', 'ADIDAS Unisex Navy Innocence Backpack', 'Cabarelli Men Black Mr.Busy', 'Kiara Women Grey Handbag', 'P119BR2 Bonn comfort Black Protected', 'Motion Perros Women Solid Grey Handbag', 'Lino Respi Highspirit Leatherite Red Handbag', 'Pitaraa Women Magenta Note', 'Murcia Women Liana Mistique Handbags', 'Rose Women Charger Handbag', 'Baggit Women Golden Purse', 'Wildcraft V.11 Red Riveted Backpack', 'Lino Smiles Women Leatherette Black P179BR2F', 'Puma Women Fitness Liplast Hobo Black Dolphin', 'Fools Pixel Tetron Pink Sappy', 'Ivory Union Pain Out Blue Handbag', 'Kiara Women Pink Handbag', 'Wildcraft Unisex Blue Duffle Glimmer', 'Kiara Women Yellow George', 'Mesmerize Unisex Black Backpack', 'Tortoise Men Black Gale Laptop FC', 'Murcia Rugby Pink Handbag', 'Be Boy Bag Women Bubblegum Green Tote Bag', 'Baggit 911 Purple Bag', 'Wildcraft Unisex Corporate Red Backpack', 'OTLS Unisex Khaki Dual Flap Bag', 'Murcia Women Hths Black Handbags', 'Treviso Women Black Clutch', 'NA2404sm01 Unisex Match Encircle Kiss Bag', 'Lino Perros Women Carve Off White Jasmine', 'Belts Brown Sling Bag', 'Murcia Women Brown Casual Handbag', 'G362 Freak Women Canvas Beige Handbag', 'AX1 Women Purple Handbag', 'Fabindia Women Magenta & Golden Potli', 'Murcia Women Leatherite Gleam Sportz', 'ADIDAS ESS Black Unisex Backpack', 'WFSD05 Perros Women Leatherette Pink Handbag', 'Lino Rebels Women Classic Black Handbag', 'Lino Perros Morgan Charcolate Black Handbag', 'AW-80-1AVDFAD84 Unisex Black Backpack', 'Kids-Boy Unisex Fundamen Black Backpack', 'Lino Perros Women Leatherette Black Kang', 'Baggit Sweater Beige Banjara Kissed Handbag', 'ADIDAS Originals Unisex ST SH112 Bag Comic Backpacks', 'Rasasi Women Brown Handbag', 'ADIDAS AS123-C1 Black Predator Backpack', 'Cathy Unisex Style Black String', 'Baggit Women Beige Handbag', 'Wildcraft Unisex Olive Green Backpack', 'Be lifestyle Bag Women Pink Tote Bag', '9915PP10 Women Black & Grey Bag', 'Puma motor Black Chaser', 'Kiara Women Affliction Pocket Blue Handbag', 'Wildcraft Pink Radiance Grey Printed Tote Rosemary', 'Vittorio Perros Slatkin Beige Handbag', 'Murcia Women Leather Hurley Deshi Tricks', 'Be For Bag Women Combo pack Tote Bags', 'SP12 Braid Casual Jetsetter Blue Backpack', 'Domyos Brown Bag', 'Sensation Perros Electra GD-100-1BDR Black/Beige Handbag', 'Peperone Outdoor Beige A669', 'Gel Theodore Dash Laptop Strawberries Backpacks', 'Murcia Women NY8500 Leather Laptop White FS4714', 'Femme Women Roxy Aviator Black Dizzy', 'Kaya Luminous A574 Black Handbag', 'Tortoise Unisex Brown Laptop Plastic', 'Wildcraft Unisex Green Backpack', 'Lino Perros Women Grey Handbag', 'Yelloe Tmber Metallic Finish Handbag', 'Rocia Women Gold Shoes.', 'Peter England Combo1 Caruvo Laptop Bag', 'Baggit Blue Printed Tote Bag', 'Mod-acc Women Swoosh Handbag', 'Lino Perros Women Check Green Handbag', 'Route Perros Women Leatherette Off Broke Handbag', 'Baggit Fluctuation Trai ...

# %%
result_data = []
lstm_data = []
for i in range(n_test_data):
  line = test_data[i]
  line_tensor = lineToTensor(line)
  output_lstm = evaluate(line_tensor)
  guess, guess_i = categoryFromOutput(output_lstm[0])
  row = []
  row.append(int(test_id[i]))
  row.append(guess)
  lstm_data.append(guess_i)
  result_data.append(row)
  
df = pd.DataFrame(result_data, columns=['id', 'category'])
df.to_csv('submission_lstm.csv', index=False)

# %%
def bin_to_category(predict_data, lstm_data):
  n_data = len(predict_data)
  y_test = []
  for i in range(n_data):
    index = np.argmax(predict_data[i])
    largest_value = predict_data[i][index]
    predict_data[i][index] = 0
    index2 = np.argmax(predict_data[i])
    largest_value_2 = predict_data[i][index2]
    if largest_value * 0.8 < largest_value_2:
      if lstm_data[i] == index or lstm_data[i] == index2:
        y_test.append(all_categories[lstm_data[i]])
      else:
        y_test.append(all_categories[index])
    else:
      y_test.append(all_categories[index])
  return y_test

# %%
def bin_to_category2(predict_data):
  n_data = len(predict_data)
  y_test = []
  for i in range(n_data):
    index = np.argmax(predict_data[i])
    y_test.append(all_categories[index])
  return y_test
